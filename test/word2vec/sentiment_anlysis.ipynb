# %%
import pandas as pd
import numpy as np
import plotly.express as px
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
from unidecode import unidecode
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import MaxAbsScaler
from sklearn.svm import LinearSVC
from gensim.models import Word2Vec
import contractions
from nltk.tokenize import sent_tokenize
from gensim.utils import simple_preprocess


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional,Embedding, Dropout,BatchNormalization, GlobalMaxPooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from transformers import BertTokenizerFast, RobertaTokenizerFast, TFRobertaModel, TFBertModel

# %%
# Reading data from two directories up
data = pd.read_csv(r'../../data/Corona_NLP_train.csv', encoding= 'ISO-8859-1')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41157 entries, 0 to 41156
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       41157 non-null  int64
#  1   ScreenName     41157 non-null  int64
#  2   Location       32567 non-null  object
#  3   TweetAt        41157 non-null  object
#  4   OriginalTweet  41157 non-null  object
#  5   Sentiment      41157 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.9+ MB

# %%
# filter the data to only conbtain the tweets and the sentiment
data = data[['OriginalTweet', 'Sentiment']]
data.head()
# Out:
#                                        OriginalTweet           Sentiment
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...             Neutral
# 1  advice Talk to your neighbours family to excha...            Positive
# 2  Coronavirus Australia: Woolworths to give elde...            Positive
# 3  My food stock is not the only one which is emp...            Positive
# 4  Me, ready to go at supermarket during the #COV...  Extremely Negative

# %%
# plot the sentiment distribution using plotly
px.histogram(data, x='Sentiment', title='Sentiment Distribution')

# %%
# The data seems balanced, we can now proceed to clean the data

# %%
# Initialize the tokenizer and other resources
tokenizer = TweetTokenizer()
stop_words = set(stopwords.words('english')) - {'not', 'no', 'never'}
lemmatizer = WordNetLemmatizer()

# %%
# function to clean the data
def preprocess_tweet(tweet):
    # Remove accents
    tweet = unidecode(tweet)
    # make the tweet to lower case
    tweet = tweet.lower()
    # Remove URLs
    tweet = re.sub(r'http\S+|www\S+|https\S+', '', tweet, flags=re.MULTILINE)
    # Remove mentions
    tweet = re.sub(r'@\w+', '', tweet)
    # Replace hastags with the space
    tweet = re.sub(r'#', ' ', tweet)
    # Remove punctuation
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    # Remove digits
    tweet = re.sub(r'\d+', '', tweet)
    # Tokenize tweet
    tokens = tokenizer.tokenize(tweet)
    # Remove stop words and do lemmatization
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    # Join tokens back to string
    tweet = ' '.join(tokens)
    # Remove multiple spaces with a single space
    tweet = re.sub(r'\s+', ' ', tweet)
    # Strip leading/trailing spaces
    tweet = tweet.strip()
    return tweet

# %%
# Apply preprocessing to the 'OriginalTweet	' column
data['cleaned_tweet'] = data['OriginalTweet'].apply(preprocess_tweet)

# %%
# Check the empty values in the cleaned_tweet column
data[data['cleaned_tweet'] == ''].shape[0]
# Out:
# 34

# %%
# Remove the empty values
data = data[data['cleaned_tweet'] != '']

# %%
data.shape
# Out:
# (41123, 3)

# %%
# Take only the cleaned tweets and the sentiment
data = data[['cleaned_tweet', 'Sentiment']]

# %%
# find the length of the tokens from the cleaned tweets
data['tweet_length'] = data['cleaned_tweet'].apply(lambda x: len(x.split()))

# %%
data = data.sort_values(by=['tweet_length'], ascending=False)
data.head(20)
# Out:
#                                            cleaned_tweet           Sentiment  \
# 27745  no mall no movie no supermarket no amazon no o...  Extremely Negative
# 35866  mdoc horhn m m brown mississippi prisoner goin...  Extremely Negative
# 21439  u oil rig not drop hugely dallas fed energy su...  Extremely Positive
# 7600   domino fall coronavirus gt world healthemergen...  Extremely Positive
# 29288  war drug firing ig amp capt cg u lost battle v...  Extremely Negative
# 10514  new play cannabis sale price skyrocketing also...            Positive
# 10023  extremely let tesco no delivery no phonecall n...  Extremely Negative
# 37156  nisan cumartesi itibariyle bbanin ta hizmetler...             Neutral
# 28699  wen every w panic buying wks ago told every st...  Extremely Negative
# 16632  bir ddettir sa permarketlerin lojistik hizmeti...             Neutral
# 13168  mar climate change locust crisis covid threate...            Negative
# 31813  big story wash post abt walmart worker death a...             Neutral
# 8374   wake news breakfast school run daily food shop...  Extremely Negative
# 9027   la escena se repite alrededor del mundo desde ...             Neutral
# 40700  amazon home low wage poor working condition am...  Extremely Positive
# 19861  anonymous donor gave u certificate tampt pet f...            Negative
# 27005  supermercados econo confirman que un empleado ...             Neutral
# 4844   impct coronavirus hve sen hw civilizd ppl figh...  Extremely Negative
# 25209  impact covid somalia food supply chain covid a...  Extremely Negative
# 39866  president trump last day rtad call dr faucis f...  Extremely Negative
#
#        tweet_length
# 27745            44
# 35866            40
# 21439            40
# 7600             39
# 29288            39
# 10514            38
# 10023            38
# 37156            38
# 28699            38
# 16632            38
# 13168            37
# 31813            37
# 8374             37
# 9027             37
# 40700            37
# 19861            37
# 27005            37
# 4844             37
# 25209            37
# 39866            37

# %%
# Filter the data such that the first row starts from 13th row
data = data.iloc[10:]
data.head()
# Out:
#                                            cleaned_tweet           Sentiment  \
# 13168  mar climate change locust crisis covid threate...            Negative
# 31813  big story wash post abt walmart worker death a...             Neutral
# 8374   wake news breakfast school run daily food shop...  Extremely Negative
# 9027   la escena se repite alrededor del mundo desde ...             Neutral
# 40700  amazon home low wage poor working condition am...  Extremely Positive
#
#        tweet_length
# 13168            37
# 31813            37
# 8374             37
# 9027             37
# 40700            37

# %%
# let's suffle the data and reset the index
data = data.sample(frac=1)
# reset the index because the index was not a good representation of the data
data = data.reset_index(drop=True)
data.head()
# Out:
#                                        cleaned_tweet           Sentiment  \
# 0  quite bizarre wuhan report new case complete u...  Extremely Negative
# 1  home decor trendy fashion local shop boutique ...             Neutral
# 2  unlike consumer mobile ascom mobile device pur...             Neutral
# 3  covid may spell end private profit healthcare ...            Positive
# 4  great toiletpaper panic via ht toiletpaper pan...            Positive
#
#    tweet_length
# 0            30
# 1            12
# 2            23
# 3            15
# 4            12

# %%
# Sentiment Column Analysis
data['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive              11419
# Negative               9916
# Neutral                7680
# Extremely Positive     6622
# Extremely Negative     5476
# Name: count, dtype: int64

# %%
# convert the sentiments to only three categories|
data['Sentiment'] = data['Sentiment'].map({'Extremely Negative':0,'Negative':0,'Neutral':1,'Positive':2,'Extremely Positive':2})

# %%
data['Sentiment'].value_counts()
# Out:
# Sentiment
# 2    18041
# 0    15392
# 1     7680
# Name: count, dtype: int64

# %%
# Split the data into X and y
X = data['cleaned_tweet']
y = data['Sentiment']

# %%
# split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (30834,) (10279,) (30834,) (10279,)

# %%
## Training our own word2vec embeddings
## create the story using the cleaned tweets
story = []
# iterate over each row in the dataframe
for index, row in data.iterrows():
    # split the tweet into sentences
    raw_sentences = sent_tokenize(row['cleaned_tweet'])
    # append the sentences to the story
    for sentence in raw_sentences:
        # sentence = simple_preprocess(sentence)
        story.append(sentence)

# %%
# create a gensim model
model = Word2Vec(vector_size=300, window=5, min_count=1, workers=4)

# %%
# Build the vocabulary
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (4508087, 26419235)

# %%
len(model.wv.key_to_index)
# Out:
# 27

# %%
[sentence for sentence in X_train]
# Out:
# ['consumer psychologist detail business need know covid business management psychology success health culture',
#  'connect live consumer panel lunch today get question answered whatas going consumer right mrx webinar coronavirus',
#  'paul krugman bash trump scheme boost oil profit stonewalling post office aid via',
#  'trending outofcontrol teenager coughing grocery store produce coronavirus',
#  'need stock food preparation worst case scenario covid betwinnervirtual',
#  'need cut another mmbbld fix oil price cure covid',
#  'coronavirus poll going grocery store food food delivered lazyvulcanpolls',
#  'ohio lockdown least april th reasses situation travel grocery store certain people still go work like law enforcement healthcare etc ohiolockdown coronavirus pandemic',
#  'commemorative earring coronavirus toiletpaper',
#  'point time three seashell demolition man invented response toilet paper hoarding madness coronavirus toiletpaper',
#  'world gone little crazy amount emptyshelved supermarket picture going around general overload covid stuff medium little well boring im glad company isa',
#  'pandemic slashing demand china model impact platts analytics chinese price race bottom electricity demand decline substantially full story',
#  'please investigate increase price independent market stallsshops west ealinguxbridge road explained increase due coronavirus doubt profiteering',
#  'covid rice price soar seven year high',
#  'stephenschork whats happening market amp whats happening oil price telegraphed amp coronavirus spark policy failure obama trump amp fed br blamed',
#  'question whoever placed note think msm helpful hyping fake news public regarding covid shopped supermarket latelyturn press pas',
#  'rhodeisland announces grocery delivery service coronavirus quarantiners partnering ri based supermarket',
#  'thank much tweeps look recent emagazine many way help youre shopping online amazon sign easyfundraising retailer online great way',
#  'thing touch grocery store could transmit coronavirus',
#  'proud part time consumer home internet wireline amp fixed wireless customer use unlimited internet data offering internet access qualifying limited income household month',
#  'oregon put million weekly funding toward oregon food bank network needed next week food bank seen increasing demand falling donation amid covid crisis',
#  'amazon richest corporation world paid almost no tax last year offering unpaid time worker sick week paid leave worker test positive virus meanwhile demand mandatory overtime shame jeff bezos',
#  'take time appreciate unsung hero coronavirus crisis grocery store cashier',
#  'want self isolate others arent risk ive classed key worker work supermarket cant many u cant not choice please self isolate place help stop spread covid',
#  'seen vermillion oh great little beach town coronavirus toiletpaper takeout delivery shoplocal',
#  'supermarket need online order service linked collection time counter service everyone else hand shopping list collect later pre arranged time help protect supply amp everyone covid',
#  'meat egg price following covid outbreak jayson lusk',
#  'greatthanks raising gas price oh died covid comment',
#  'thing get desperate folk might start taking hostage demand toiletpaper ransom coronavirus',
#  'weve lowered price due coronavirus lockdownuknow selfcaresunday',
#  'supermarket confined space lot people could leave shopper vulnerable',
#  'awe increased storage capacity constant contact provider make sure stock readily available number continue increasea',
#  'humanity creator not fucking consumer coronavirus',
#  'truly country not designed total lockdown everyone many people lower class could die hunger covid virus even get considering lack fund stock food supply',
#  'country put measure support population regulating price necessity yet govt focusing issuing directive wonder dont know hunger kill faster covid staysafeug',
#  'video critical care nurse emotional please unable find fresh food long shift',
#  'looking work coronavirus layoff covid coronavirus employment job',
#  'today roundup shared story quick shift medical garment',
#  'friend posted facebook doesnat want identity store work public obviously needed share say covid grocery store employee dontbeaasshole stayhomesavelives',
#  'webcast global consumercovidconsumer confidence',
#  'got email asda amend order item no longer available people still panic buying there people like actually ill need food ill go shopping risk passing others coronavirus covid',
#  'key highlight pm modi addressing resolve restraint covid economic task force janta curfew nd march no scarcity basic food amp medicine normal buying not panic buying avoid public gathering indiafightscorona',
#  'friend mine life wealthy area food drive local food bank struggling high demand covid found disproportionately people willing give food came council flat area',
#  'competiscan insight team released study consumer perception regarding covid client access full report competiscan coronavirus covid',
#  'smart danish store end hand sanitizer shortage due hoarding introducing tiered pricing first bottle second bottle coronavirus',
#  'food supply chain strong despite empty shelf food supply chain u strong grocery store recently seen bare shelf scary site',
#  'surge online shopping drive major increase themed fraud attempt full article',
#  'spacex making hand sanitizer building face shield donate fight coronavirus coronavirus coronavirusoutbreak covid covid medtwitter coronaviruschallenge corona pandemic batflu wuhan quarantine',
#  'hey people twitter place could find global best practice response covid example story specific supermarket successfully managed influx people might positive thing spread around coronavirus',
#  'gi feature interview half time talk energy outlook advisor price not going rise enough save shale',
#  'remember price gouging state emergency illegal business cannot increase price spread word covid coronavirus floridalockdown',
#  'good morning brother law working site southampton no hand sanitizeras wipe site say one positive donat use finger print scanner',
#  'help eat well limit movement coronavirus crisis download application smartphones make easier recover food timefind restaurant grocery store near deliver healthy meal home',
#  'people hamster toilet paper sell ebay insane price whole new level scum like seriously show compassion dont try profit coronavirus covid',
#  'would like request honorable prime minister e major supermarket shut week see result measure covid open pharmacy online shopping service convenience shop essential item',
#  'yesi kept distance assume going supermarket caught',
#  'click link igd resource find engaging industry read news food consumer good sector situation developing follow regular content',
#  'size online food shopping queue live london coronavirus uklockdown',
#  'consumer taking restaurant used dinein not really latest data covid amp consumer behavior change',
#  'must read exclusive australian nursing federation called coronavirus generation version plague demanding curfew total aged care lockdown school closure hour supermarket trading stop spread covid',
#  'give miss call set shop live min join telegram group download app covid restuarant retail retailer food di',
#  'nurse looking immunecompromised grocery store employee stocking food cleaning supply public transportation remains essential thank dedicated employee keep travel safe transit coronavirus covid',
#  'clapping frontline nh worker carers supermarket staff everyone else risking life health care others quiet corner london much gratitude clapforcarers clapforthenhs clapforourcarers coronavirus nhsthankyou',
#  'parent facing unique unprecedented stress right spoke expert offer advice managing stress managing stress child read covid coronavirus stress parenting',
#  'really hope government would start ban online retailer price gouging mask hand sanitizers anti bacterial wipe n alcohol unfair people arent well price surging almost x normal price covid',
#  'herd immunity cant work herd mentality stop selfish look filter fake news stopfakenews stoppanicbuying stopcoronavirus stopcovid coviduk coronavirus',
#  'shopper waiting enter grocery store toronto canada practiced social distancing leaving significant space person u canada agreed close border two country non essential traffic spread',
#  'went grocery store pretty good mostly packaged meat got meat butcher everything wantedgot list not even hording right stuffoh well coronavirus selfquarantine',
#  'regarding effect partner amis reminds u not supply issue behavioral change food security refraining reduces stress global market',
#  'best thing ab covid gas price went',
#  'food grain stock last next two year state not face shortage govt get coronavirus live update indiafightscorona coronavirusoutbreak',
#  'easy panic amp rightly considering dealing sanitize hand avoid crowd stay indoors much eat good food amp drink water beef immunity maintain high index suspicion stay safe coronavirus corona covid pandemic',
#  'market basket reported tuesday employee salem store died coronavirus two employee store tested positive',
#  'coronavirus covid reaction album wowa price panama city fl post pic gas price live covid coronavirus',
#  'started fixing credit score last year ready real estate price surely drop due covid not waiting call dm u today davecom visit website',
#  'ny wilding rn coronavirus nofood',
#  'uk consumer poll indicates majority expect covids impact last month march expect increase next tracker see full result coronavirus consumer confidence tracker',
#  'donald want raise shipping price coronavirus',
#  'last night actually dreamed hand sanitizer gulag coronavirus',
#  'hi guy bromley n local asian store charging absurd price poultry rice meat family already suffering poverty apart reporting cma else done amp want take action',
#  'item coming soon shoponthcom sundaymorning sundaymotivation stayhome socialdistancing moneyyaya metoo plussizefashion please curvynstyle highheels cuteclothes quarantineandchill online onlineshopping youhadallday shopmycloset shopping shop lockdown',
#  'opec deal wonat save covid crashed oil price asia time',
#  'nine supermarket one day including lidhells maybe timing wrong keep missing delivery supermarket keep talking shopping since hr mind covid coronavirus stophoarding panicbuyinguk london',
#  'bike ride yesterday thought even not self isolated nothing open sans grocery store covidus coronavirus',
#  'manager telling discussion customer wanted take rds shelf cat food could selfisolate cat month no others need shop supermarket coronavirus covid',
#  'corona picture moment lady corona coronavirus socialdistancing shelterinplace toiletpaper mask neworleans',
#  'current situation kyoto kyoto coronavirus covid not quarantined government restaurant cafe shopping mall open food toilet paper kitchen paper tissue not stock therere no hoarding panic',
#  'wow tech company may thrive amazon delivery infrastructure strained covid outbreak spark surge online shopping cc',
#  'son work small italian supermarket people allowed time apart shelf fully stocked queue long though people going shopping every day instead weekly mainly socialise got better uk response coronavirus',
#  'homemade bread cheap easy think actually need shop time not everyone afford stock freezer store food',
#  'buy fresh grocery organic food everyday essential online amazon day delivery possible eligible order via coronavirus selfisolation lockdown quarantine',
#  'know anyone else done yet artist might financially affected covid please reply commission example price let try get thread going need right get buyer',
#  'covid global pandemic made altered consumer behaviour made marketer think strategy data challenge remain demand even greater attention look deliver customer value consistently',
#  'heading grocery store want anything socialdistancing',
#  'story grocery store worker dying covid note walmart kroger starting check temp employee ok not check temp customer letting store',
#  'sign bloomberg intelligence amp bimco shipping webinar discus current landscape challenge ahead industry face two black swan event coronavirus collapse oil price',
#  'retailgazette pm borisjohnson downingstreet speaking supermarket boss effort keep supply flowing overcome panicbuying gripping uk coronavirus pandemic covid stockpilinguk pana',
#  'notgoingout shame utter idiot isnt joke look horrendous scene italy really want',
#  'ever witness violent behavior towards supermarket worker covid pandemic covidaustralia coronavirusaus australian australia australialockdown',
#  'sainsbury becomes first major retailer sell big issue halt street sale find',
#  'commission working area interest european identifying impact various area policy measure area consumer protection eu level thank prompt action',
#  'oil future ny jumped barrel noon price spxa nasa wtia golda silvera practise trading oil free demo coronavirus covid covidau donaldtrump coronavirusoutbreak',
#  'also call customer say cashier coughed wanted sent home',
#  'yall walked two half mile supermarket last night quieter usual eerie suspense permeated dessert aisle deserted almost no staple egg bread pasta etc covid',
#  'lock would hurt people ooo covid doesnat check account balance think feed even though told stock money no dey story long youave food table brother thank god oo',
#  'news positive test came day gov charlie baker issued new public health order related grocery store including temporary ban reusable bag',
#  'every supermarket iave amp britain past week new sticker new label new banner new sleeve barrier new barrier outside queue new poster coronavirus canat seem get glove staff amp nh canat get mask',
#  'spot meat aldi',
#  'help covid doubled demand meal houston food bank help family community',
#  'scammer trying take advantage vulnerable right related scam click learn look',
#  'new smg research highlight covid impacting consumer behavior restaurant industry',
#  'owner manager local supermarket tested positive covid manger kept working past week even though symptom virus sister work',
#  'month pandemic nynj amp toilet paper shelf still empty grocery likely run fruit veggie toilet paper also cleaning supply not fair u bought moderately per government suggestion toiletpaper coronavirus virus',
#  'supermarket staff hearing pub closure announcement',
#  'scammer follow headline taking advantage coronavirus pandemic ftc put together great resource help protect bevigilant see scam fraud covid cybersecurity security pinellas',
#  'weekas wtf update hospital ask state temporarily raise price trump hasnat reopened open enrollment not covered hospital firing doctorsnurses speaking lack ppe trump speaking drug cartel coronavirus covid',
#  'good read b e c r e f u l onlineshopping malware identitythiefs rt important tip safe online shopping post covid via',
#  'going vegan sushi wine travelchatsa',
#  'aminimum basic operationsa doesnat include welcoming customer retail store anormala operation covid',
#  'iad like see emergency order requiring grocery store personnel tested coronavirus people entering store tested testing sick wonat slow spread given long incubation period vir',
#  'michiganas food bank network working respond covid pandemic read full article foodsecurity morefoodmoreoftenmorepeople covidresponse',
#  'consumer behavior changing result coronavirus people quarantine look way make purchase without needing go public behavior may lead unprecedented ecommerce growth read partner eshopworld',
#  'australian arm consumer good company announced donate million aud disinfectant product rb corporatepartnerships australian donation covid charityaustralia crisis',
#  'thank managed register elderly parent online shopping phone answered less sec pleased live distance volunteer prioritise elderly not internet savvy like parent stayhomesavelives coronavirus',
#  'consumerfacing industry benefiting increased online app order demand social distancing amp business must ensure website apps accessible everyone via webaccessibility socialdistancing',
#  'safeway hiring safeway hiring job maryland virginia dc delaware area keep food supply demand pandemic find apply',
#  'prevent spread covid laundry consumer report',
#  'live look dodging people make ft space grocery store',
#  'requesting mp mla distribute free mask sanitizer people region help save coronavirus',
#  'stand line buy grocery wear mask carry hand sanitizer pocket use liberally read virus pandemic handsanitizer coronavirus prepping preparedness foodstorage',
#  'im completely turned going seeing video lady spitting fresh produce supermarket knowing damn well tested positive coronavirus fkn wicked',
#  'lovely people work needwant temporary work sainsburys sydenham im hiring hit hiring temporarywork temporaryvacancy coronavirus covid coviduk work job musicaltheatre westend sydenham retail lockdownlondon',
#  'nothing change reasonable supermarket bank doctor pharmacy visited otherwise social contact reduced not accept rule stupidity ignorance legal basis curfew',
#  'first experience window shopping today no deliverycollection available supermarket woman strange idea fun coronavirus coronavirusuk',
#  'regular bar soap good hand sanitizer professor explains best kill',
#  'yet another incident racism amidst coronavirus frenzy two people denied entry grocery store hyderabad due facial characteristic watch video know report tanmay mehta covid lockdown northeast indiafightscoronavirus',
#  'consequence stockmarketcrash short term credit dry employer no money pay worker buy inventory pay supplier bankruptcygtlayoffsgtdemand fallsgtconsumption end traumatic damage civilwar dowjones sp usa trump coronavirus sick depression',
#  'begun provide food covid outbreak demand high site',
#  'number heading right direction help u pack pantry',
#  'last one month alone used liter antibacterial hand wash ml alcohol based hand sanitizer apart provided place coronavirus',
#  'customer asked please respect hour reserved highrisk customer coronavirus',
#  'capital always flow multiplies stay china provide best price covid make price cheaper win back customer thats capitalism',
#  'two new kind hit market exclusively county grab gone',
#  'need food stop exposing child virus stock house enough food last covid period saved innocent soul',
#  'dr birx warns not time go grocery store next week possible try avoid grocery store covid coronavirus stayathome',
#  'shouldnt world leading free market economy let market force decide cheap oil great consumer amp economy destroyed coronavirus im sure developing world grateful low fuel price russia saudi aramco really going cut bpd',
#  'neda said consumer business survey aiming assess impact coronavirus disease covid ecq covidph covid covidph',
#  'asking price house canberra continue rise despite economic impact covid emergency canberra experienced secondlargest increase property listing nation march',
#  'people desperation mode regarding coronavirus handsanitizer dispenser stolen kci coronaviruspandemic coronavirusupdate coronavirusoutbreak covid',
#  'imagine year old think lick shit grocery store father oh wait recording coronavirus',
#  'another day jungle coronavirus grocery stock food freeme shruglife',
#  'ireland covid questionwrite name people love world walk promgo open pubstand close supermarketdont bother washing hand not hangin ur friendsnow put line name let die stayathome',
#  'utterly astounds middle coronavirus pandemic people worried catching potentially deadly respiratory disease remove face mask fag queue supermarket outfuckingstanding',
#  'coronavirus could worsen hunger developing world',
#  'pulse oximeter price went x amazon uk still ebay reasonable price aps need one check oxygen saturation time day good early warning sign case coronavirus',
#  'closely tracking evolving covid pandemic impact retail industry lpapas response stay tuned latest industry news updated every weekday amp running list store closure',
#  'remember one not part solution part problem coronavirus',
#  'two metre ft inch yard height door hockey stick half parking space broom anyone know thats really tall plus bit many people not following yesterday supermarket walk coronavirus',
#  'dick sporting good evokes force majeure abate store rent covid pittsburgh retail covid retailvscorona',
#  'basically youare saying others tout blazing fast speed consumer uniquely selling smokeaif canat truly deliver speed promising getting lot back',
#  'panic created mess stop breath australia mwe plentiful food stop hoarding first class medical facility everybody need put head together refocus covid wonat destroy losing',
# ...
#  'icymi alberta inflation rate outpaces canadian average alberta inflation consumer price coronavirus covid oilprices calgary yyc edmonton business businessnews',
#  'covid crisis consumer shopping online ever millennials say theyre likely buy amazon site founder amp ceo explains amazon business appeal distinctive demographic',
#  'stressed health clinic due covid barrel selfisolating home barrel stockpiling supermarket barrel',
#  'went supermarket yesterday letting ineverybody queued politely metre apart got shelf full everything stock coronaviruslockdownuk covid',
#  'grateful god without also grateful people thank doctor pharmacist nurse grocery store employee delivery worker essential worker helping u get indebted',
#  'breaking news coronavirus new supermarket worker share story',
#  'run drinking water go walk nearest grocery store donat forget wear mask socialdistancing carry hand sanitizer fightcovid',
#  'heard guy ripping people high priceswhy man covid not enough',
#  'special place hell people panic buy knowing full well deliberately depriving others essential thing food pet desiccated arse scraping hike price profit crisis',
#  'wondering cant buy essential item grocery store right supply chain not prepared pandemic like coronavirus measure government take prepared future',
#  'really starting see impact covid home town empty shelf supermarket empty road empty station rush hour shout unseen work behind scene making transition work home smoother hoping working fm home tomor',
#  'social distancing even buy food essential example learn denmark supermarket lessen chance infection coronavirus covid kccaatwork',
#  'coronavirus sent price oil plunging u staying home not filling tank frequently benefiting lower price',
#  'seen covid related potential scam quack cure',
#  'school restaurant retail establishment closed people staying home still need grocery',
#  'supermarket forced throw r lakh worth food woman coughed prank',
#  'wonder no deal brexit plan helped didnt supermarket wonder coronavirus cost world adapting climate change let green world',
#  'canadian ado not need panica food shortage amid covid expert say global news published canada news medium news',
#  'tip avoid scam homework come donation charity crowdfunding site let anyone rush making donation someone want donation cash gift card wiring money tip',
#  'coronavirus supermarket shopping looking amore normala say tesco bos uk shopping supermarket panicbuying coronavirus covid health staysafe stayathome dontbeafool thinkofothers followtherules socialdistancing lockdown',
#  'rent deal needed uk restaurant survive coronavirus covid hospitality hospitalityindustry',
#  'trump say gas price low lot people happy people quarantine coronaviruspandemic coronavirus gasprices',
#  'remember wash hand regularly soap sanitize alcohol based hand sanitizer avoid touching face stay safe coronaviruspandemic coronavirus covid',
#  'floridian past time become going grocery store everyday drove floridia not staying home traffic heavy day day im sure many not essentialworker pinellas county not practicing socialdistancing holdchinaaccountable coronaviruspandemic',
#  'uslisted share chemical company fell even oil price rose second day prospect world major oil producer could reach deal limit output petchemindustry petrochemical stockmarket oilcrash covid coronavirus',
#  'india likely export mn sugar earlier estimate drop global price due coronavirus outbreak make overseas sale unprofitable mill lower indian export could support globa',
#  'dont want go supermarket no choice no slot week delivery click collect supermarket need supermarket coronavirus infectioncontrol publichealth government food queue nightmare',
#  'sign time day boff joined saddos st queue tesco coronavirus panic panicbuying food basic uk tesco extra',
#  'supporting branch help please visit essential check branch finder call check making visit',
#  'grocery store must like burning man feel every year iam trying trade fruit loop tp hell iall knit sweater sweet ply coronavirus toiletpaperapocalypse',
#  'bitcoin safe covid pandemic mean price kitco news',
#  'following governmentas latest advice ecommerce business no physical retail store operating amp delivering standard product normally customer service amp sale team working remotely trying maintain business usual',
#  'devil went looking roll steal bind clenching behind willing make deal',
#  'strict rationing force local supermarket guy front tried buy four bottle vodka two confiscated coronavirus',
#  'dont believe douchebag say curing covid he gonna raise price drug like last time',
#  'everyone safe need supply there store page get theyre gone ebay ebayseller ebaydeals ebayshop ebaystore ebayauctions coronavirus toiletpaperpanic toiletpaper freeshipping onlineshopping onlinemarketing shopmycloset',
#  'covid online shopping history thread not flex itas problem',
#  'read latest guidance protect finance coronavirus outbreak',
#  'recently set food business coronavirus stayathome period still comply food safety legislation make sure food not cause harm injury consumer musta',
#  'oil lng producer bracing several month depressed price',
#  'people toronto grocery shopping online yes staying day line store not hoard simple task basic grocery shopping taking day',
#  'larger supermarket chain adopt standard opening hour sunday rather closing pm wider window lower volume shopper lessen risk coronavirus crosscontamination',
#  'police ask carers supermarket delivery driver look sign domestic abuse coronavirus',
#  'toilet paper line coronavirus pandemic quarantine itas control toiletpaper coronavirus covid pandemic quarantine stayathome saferathome shelterinplace',
#  'icymi estace lauder producing hand sanitizer help fight coronavirus esteelauder coronavirus',
#  'no landlord md allowed raise rent crisis take action',
#  'morning briefing crude oil price skyrocketed largest day gain record crudeoil coronavirus read risk warning retail cfd account lose money',
#  'ceo davy said one point last month service compared time last year business saw uptick due coronavirus crisis coronavirusaus covidaustralia',
#  'online grocery delivery provider struggle sharp rise covid related demand customer report wait day online food order company assess option cbc news',
#  'oil price plunge year low coronavirus hurt demand amp saudi arabia russia battle market share u wti price tumble bbl end lowest since feb wti price track worst month ever via',
#  ...]

# %%
# create features for the X_train, X_test using the word2vec embeddings
x_train_word2 = np.array([np.mean([model.wv[word] for word in sentence if word in model.wv] or [np.zeros(100)], axis=0) for sentence in X_train])
x_test_word2 = np.array([np.mean([model.wv[word] for word in sentence if word in model.wv] or [np.zeros(100)], axis=0) for sentence in X_test])

# %%
print(x_train_word2)
# Out:
# [[-3.7058596e-02 -3.0994322e-02  8.3870944e-03 ... -1.3036024e-02
#   -4.0876202e-02  7.8900442e-02]
#  [-3.0395171e-02 -2.6520470e-02 -7.9622697e-03 ... -8.8595198e-03
#   -4.9609497e-02  8.4194988e-02]
#  [-3.9508767e-02 -3.2794036e-02 -1.5287841e-02 ... -1.9530347e-05
#   -4.9790360e-02  6.5771021e-02]
#  ...
#  [-2.7701473e-02 -1.8611019e-02 -3.2857468e-03 ... -1.3021737e-02
#   -2.7716286e-02  6.3945882e-02]
#  [-3.3871822e-02 -2.4512006e-02  1.1593896e-02 ...  3.2961229e-03
#   -2.9511815e-02  8.4891744e-02]
#  [-3.8540415e-02 -9.1845184e-05  1.0828469e-03 ... -1.7626368e-02
#   -3.6644034e-02  5.1747572e-02]]

# %%
# Find rows where all values are non-zero
rows_all_non_zero = x_train_word2[np.all(x_train_word2 == 0, axis=1)]
print(rows_all_non_zero)
# Out:
# []

# %%
# check the shape of the x_train_word2 and x_test_word2
print("The shape of the x_train_word2 is: ", x_train_word2.shape)
print("The shape of the x_test_word2 is: ", x_test_word2.shape)
# Out:
# The shape of the x_train_word2 is:  (30834, 300)
# The shape of the x_test_word2 is:  (10279, 300)

# %%
# create a function to fit different models
def fit_model(model, X_train, y_train, X_test, y_test):
    print('Fitting the Model \n')
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    print('Accuracy: ', accuracy)
    print('\nPrecision: ', precision)
    print('\nRecall: ', recall)
    print('\nF1 Score: ', f1)
    print('\nConfusion Matrix: \n', confusion_matrix(y_test, y_pred))
    print('Classification Report: \n', classification_report(y_test, y_pred, zero_division=0))

# %%
# Fit a logistic regression model to the data
logreg = LogisticRegression(max_iter = 1000)   
fit_model(logreg, x_train_word2, y_train, x_test_word2, y_test)
# Out:
# Fitting the Model
#
# Accuracy:  0.5010215001459286
#
# Precision:  0.4991411072722821
#
# Recall:  0.5010215001459286
#
# F1 Score:  0.47362460142082236
#
# Confusion Matrix:
#  [[1584  129 2143]
#  [ 538  284 1047]
#  [1118  154 3282]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.41      0.45      3856
#            1       0.50      0.15      0.23      1869
#            2       0.51      0.72      0.60      4554
#
#     accuracy                           0.50     10279
#    macro avg       0.50      0.43      0.42     10279
# weighted avg       0.50      0.50      0.47     10279

# %%
# fit a random forest model to the data
rf = RandomForestClassifier()
fit_model(rf, x_train_word2, y_train, x_test_word2, y_test)
# Out:
# Fitting the Model
#
# Accuracy:  0.5070532152933165
#
# Precision:  0.5037836838067045
#
# Recall:  0.5070532152933165
#
# F1 Score:  0.4934685532389234
#
# Confusion Matrix:
#  [[1718  203 1935]
#  [ 518  461  890]
#  [1247  274 3033]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.45      0.47      3856
#            1       0.49      0.25      0.33      1869
#            2       0.52      0.67      0.58      4554
#
#     accuracy                           0.51     10279
#    macro avg       0.50      0.45      0.46     10279
# weighted avg       0.50      0.51      0.49     10279

# %%
# fit the naive bayes model to the data
nb = MultinomialNB()
fit_model(nb, x_train_word2, y_train, x_test_word2, y_test)
# Out:
# Fitting the Model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[346], line 3
#       1 # fit the naive bayes model to the data
#       2 nb = MultinomialNB()
# ----> 3 fit_model(nb, x_train_word2, y_train, x_test_word2, y_test)
#
# Cell In[342], line 4, in fit_model(model, X_train, y_train, X_test, y_test)
#       2 def fit_model(model, X_train, y_train, X_test, y_test):
#       3     print('Fitting the Model \n')
# ----> 4     model.fit(X_train, y_train)
#       5     y_pred = model.predict(X_test)
#       6     accuracy = accuracy_score(y_test, y_pred)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\naive_bayes.py:772, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     770 n_classes = Y.shape[1]
#     771 self._init_counters(n_classes, n_features)
# --> 772 self._count(X, Y)
#     773 alpha = self._check_alpha()
#     774 self._update_feature_log_prob(alpha)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\naive_bayes.py:894, in MultinomialNB._count(self, X, Y)
#     892 def _count(self, X, Y):
#     893     """Count and smooth feature occurrences."""
# --> 894     check_non_negative(X, "MultinomialNB (input X)")
#     895     self.feature_count_ += safe_sparse_dot(Y.T, X)
#     896     self.class_count_ += Y.sum(axis=0)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py:1489, in check_non_negative(X, whom)
#    1486     X_min = xp.min(X)
#    1488 if X_min < 0:
# -> 1489     raise ValueError("Negative values in data passed to %s" % whom)
#
# ValueError: Negative values in data passed to MultinomialNB (input X)

# %%
# fit the linear svc model to the data
svc = LinearSVC()
fit_model(svc, x_train_word2, y_train, x_test_word2, y_test)
# Out:
# Fitting the Model
# C:\Users\engma\AppData\Roaming\Python\Python38\site-packages\sklearn\svm\_classes.py:32: FutureWarning:
#
# The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
# Accuracy:  0.49751921393131626
#
# Precision:  0.49473539370695635
#
# Recall:  0.49751921393131626
#
# F1 Score:  0.4665161569874982
#
# Confusion Matrix:
#  [[1615  105 2136]
#  [ 577  226 1066]
#  [1154  127 3273]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.48      0.42      0.45      3856
#            1       0.49      0.12      0.19      1869
#            2       0.51      0.72      0.59      4554
#
#     accuracy                           0.50     10279
#    macro avg       0.49      0.42      0.41     10279
# weighted avg       0.49      0.50      0.47     10279

# %%
# fit the xgboost model to the data
xgb_model = xgb.XGBClassifier()
fit_model(xgb_model, x_train_word2, y_train, x_test_word2, y_test)
# Out:
# Fitting the Model
#
# Accuracy:  0.5006323572331939
#
# Precision:  0.4957598947264716
#
# Recall:  0.5006323572331939
#
# F1 Score:  0.4919925498271207
#
# Confusion Matrix:
#  [[1746  285 1825]
#  [ 510  536  823]
#  [1349  341 2864]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.48      0.45      0.47      3856
#            1       0.46      0.29      0.35      1869
#            2       0.52      0.63      0.57      4554
#
#     accuracy                           0.50     10279
#    macro avg       0.49      0.46      0.46     10279
# weighted avg       0.50      0.50      0.49     10279
